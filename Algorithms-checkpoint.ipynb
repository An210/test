# %%
import numpy as np

def minimumBribes(q):
    count = 0
    ini = False
    t = {}
    if(ini == False):
        i= 0
        for x in range(len(q)):
            t.append(2)
        newarr= np.dstack((q, t))
        ini = True
    print(newarr)
    for i  in range(len(q) - 1):
        for i in range(len(q)):
            if(i < len(q) - 1):
                if(q[i] > q[i+1]):
                    newarr[0][i][1] = newarr[0][i][1] - 1

                    q[i], q[i+1] = q[i+1], q[i]
                    count += 1
                i += 1
                
    print(newarr)         
    print(newarr[0][4])  
    print(q)
                
   
    
t =[2,5,1,3,4]
minimumBribes(t)
# Out:
# [[[2 2]
#   [5 2]
#   [1 2]
#   [3 2]
#   [4 2]]]
# [[[2 1]
#   [5 1]
#   [1 1]
#   [3 1]
#   [4 2]]]
# [4 2]
# [1, 2, 3, 4, 5]

# %%
def minimumBribes(q, i): 
    
    if (i < q):
        i += 1
        minimumBribes(q, i)
    print(i)
minimumBribes(2,0)
# Out:
# 2
# 2
# 1

# %%
import numpy as np

def minimumBribes(q):
    count = 0
    ini = False
    t = {}
    if(ini == False):
        i= 0
        for x in range(len(q)):
            t.append(2)
        newarr= np.dstack((q, t))
        ini = True
    print(newarr)

        if(i < len(q) - 1):
            if(q[i] > q[i+1]):
                newarr[0][i][1] = newarr[0][i][1] - 1

                q[i], q[i+1] = q[i+1], q[i]
                count += 1

                
    print(newarr)         
    print(newarr[0][4])  
    print(q)
                
   
    
t =[2,5,1,3,4]
minimumBribes(t)
